# %%
import io
import chess.pgn
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import chess
import chess.pgn

# Create the SQLAlchemy engine (use your actual credentials)
engine = create_engine('postgresql://postgres:anypass@localhost:5432/chess-ml')

# Games Table
games = "SELECT * FROM games;"
df_table1 = pd.read_sql(games, engine)

# Moves Table
moves = "SELECT * FROM moves;"
df_table2 = pd.read_sql(moves, engine)

# Players Table
players = "SELECT * FROM players;"
df_table3 = pd.read_sql(players, engine)

pgn_data = df_table1['pgn']  # Extract the PGN column

def pgn_to_board_states(pgn_string):
    pgn = io.StringIO(pgn_string)  # Convert the PGN string to a file-like object
    game = chess.pgn.read_game(pgn)  # Parse the game
    board_states = []
    board = game.board()

    # Loop through the moves and convert to matrix form
    for move in game.mainline_moves():
        board.push(move)
        board_states.append(board_to_matrix(board))
    
    return board_states

def board_to_matrix(board):
    piece_map = board.piece_map()
    matrix = np.zeros((8, 8, 12), dtype=int)

    for position, piece in piece_map.items():
        row = position // 8
        col = position % 8
        piece_type = piece.piece_type - 1  # Piece types range from 1 (Pawn) to 6 (King)
        color_offset = 0 if piece.color == chess.WHITE else 6
        matrix[row, col, piece_type + color_offset] = 1

    return matrix

def print_board_states(board_states):
    # Create an empty chess board object
    board = chess.Board()

    # Loop through the board states and display each one
    for i, state in enumerate(board_states):
        print(f"\nBoard after move {i + 1}:")
        print(board)  # Print the current board in a chess format
        
        # Simulate the next move on the board
        if i < len(board_states) - 1:
            move = board.pop()  # Undo the last move to get back to the previous state

# Dictionary to store board states by GameId
game_board_states = {}

# Loop through all games in the DataFrame
for index, row in df_table1.iterrows():
    game_id = row['game_id']  # Extract GameId
    pgn_string = row['pgn']  # Extract PGN string
    try:
        # Generate the board states for the current game
        board_states = pgn_to_board_states(pgn_string)
        
        # Save the board states for the game in the dictionary
        game_board_states[game_id] = board_states
        print(f"Processed GameId: {game_id}, Number of board states: {len(board_states)}")
    
    except Exception as e:
        print(f"Failed to process GameId: {game_id} due to error: {e}")

print("Finished processing all games.")
# Out:
# Processed GameId: 1, Number of board states: 56
# Processed GameId: 2, Number of board states: 57
# Processed GameId: 3, Number of board states: 79
# Processed GameId: 4, Number of board states: 90
# Processed GameId: 5, Number of board states: 74
# Processed GameId: 6, Number of board states: 54
# Processed GameId: 7, Number of board states: 76
# Processed GameId: 8, Number of board states: 94
# Processed GameId: 9, Number of board states: 137
# Processed GameId: 30, Number of board states: 25
# Processed GameId: 10, Number of board states: 85
# Processed GameId: 11, Number of board states: 68
# Processed GameId: 12, Number of board states: 65
# Processed GameId: 13, Number of board states: 48
# Processed GameId: 14, Number of board states: 79
# Processed GameId: 15, Number of board states: 53
# Processed GameId: 16, Number of board states: 31
# Processed GameId: 17, Number of board states: 139
# Processed GameId: 18, Number of board states: 49
# Processed GameId: 19, Number of board states: 121
# Processed GameId: 20, Number of board states: 100
# Processed GameId: 21, Number of board states: 135
# Processed GameId: 22, Number of board states: 64
# Processed GameId: 23, Number of board states: 71
# Processed GameId: 24, Number of board states: 49
# Processed GameId: 25, Number of board states: 86
# Processed GameId: 26, Number of board states: 51
# Processed GameId: 27, Number of board states: 117
# Processed GameId: 28, Number of board states: 29
# Processed GameId: 29, Number of board states: 61
# Processed GameId: 31, Number of board states: 30
# Processed GameId: 32, Number of board states: 127
# Processed GameId: 33, Number of board states: 40
# Processed GameId: 34, Number of board states: 101
# Processed GameId: 35, Number of board states: 56
# Processed GameId: 36, Number of board states: 91
# Processed GameId: 37, Number of board states: 55
# Processed GameId: 38, Number of board states: 68
# Processed GameId: 39, Number of board states: 45
# Processed GameId: 40, Number of board states: 35
# Processed GameId: 41, Number of board states: 59
# Processed GameId: 42, Number of board states: 41
# Processed GameId: 43, Number of board states: 46
# Processed GameId: 44, Number of board states: 46
# Processed GameId: 45, Number of board states: 55
# Processed GameId: 46, Number of board states: 35
# Processed GameId: 47, Number of board states: 50
# Processed GameId: 48, Number of board states: 75
# Processed GameId: 49, Number of board states: 89
# Processed GameId: 50, Number of board states: 49
# Processed GameId: 51, Number of board states: 85
# Processed GameId: 52, Number of board states: 23
# Processed GameId: 53, Number of board states: 77
# Processed GameId: 54, Number of board states: 43
# Processed GameId: 55, Number of board states: 67
# Processed GameId: 56, Number of board states: 54
# Processed GameId: 57, Number of board states: 10
# Processed GameId: 58, Number of board states: 47
# Processed GameId: 59, Number of board states: 77
# Processed GameId: 60, Number of board states: 79
# Processed GameId: 61, Number of board states: 29
# Processed GameId: 62, Number of board states: 45
# Processed GameId: 63, Number of board states: 67
# Processed GameId: 64, Number of board states: 70
# Processed GameId: 65, Number of board states: 23
# Processed GameId: 66, Number of board states: 83
# Processed GameId: 67, Number of board states: 47
# Processed GameId: 68, Number of board states: 136
# Processed GameId: 69, Number of board states: 60
# Processed GameId: 70, Number of board states: 42
# Processed GameId: 71, Number of board states: 92
# Processed GameId: 72, Number of board states: 73
# Processed GameId: 73, Number of board states: 77
# Processed GameId: 74, Number of board states: 38
# Processed GameId: 75, Number of board states: 89
# Processed GameId: 76, Number of board states: 72
# Processed GameId: 77, Number of board states: 150
# Processed GameId: 78, Number of board states: 80
# Processed GameId: 79, Number of board states: 59
# Processed GameId: 80, Number of board states: 38
# Processed GameId: 81, Number of board states: 98
# Processed GameId: 82, Number of board states: 37
# Processed GameId: 83, Number of board states: 38
# Processed GameId: 84, Number of board states: 54
# Processed GameId: 85, Number of board states: 33
# Processed GameId: 86, Number of board states: 73
# Processed GameId: 87, Number of board states: 120
# Processed GameId: 88, Number of board states: 84
# Processed GameId: 89, Number of board states: 50
# Processed GameId: 90, Number of board states: 63
# Processed GameId: 91, Number of board states: 51
# Processed GameId: 92, Number of board states: 97
# Processed GameId: 93, Number of board states: 70
# Processed GameId: 94, Number of board states: 102
# Processed GameId: 95, Number of board states: 19
# Processed GameId: 96, Number of board states: 67
# Processed GameId: 97, Number of board states: 53
# Processed GameId: 98, Number of board states: 45
# Processed GameId: 99, Number of board states: 82
# Processed GameId: 100, Number of board states: 50
# Processed GameId: 101, Number of board states: 78
# Processed GameId: 102, Number of board states: 51
# Processed GameId: 103, Number of board states: 67
# Processed GameId: 104, Number of board states: 109
# Processed GameId: 105, Number of board states: 71
# Processed GameId: 106, Number of board states: 70
# Processed GameId: 118, Number of board states: 56
# Processed GameId: 107, Number of board states: 65
# Processed GameId: 108, Number of board states: 67
# Processed GameId: 109, Number of board states: 101
# Processed GameId: 110, Number of board states: 62
# Processed GameId: 111, Number of board states: 40
# Processed GameId: 112, Number of board states: 48
# Processed GameId: 113, Number of board states: 57
# Processed GameId: 114, Number of board states: 47
# Processed GameId: 115, Number of board states: 47
# Processed GameId: 116, Number of board states: 37
# Processed GameId: 117, Number of board states: 98
# Processed GameId: 119, Number of board states: 90
# Processed GameId: 120, Number of board states: 59
# Processed GameId: 121, Number of board states: 92
# Processed GameId: 122, Number of board states: 119
# Processed GameId: 123, Number of board states: 92
# Processed GameId: 124, Number of board states: 36
# Processed GameId: 125, Number of board states: 39
# Processed GameId: 126, Number of board states: 81
# Processed GameId: 127, Number of board states: 29
# Processed GameId: 128, Number of board states: 45
# Processed GameId: 129, Number of board states: 67
# Processed GameId: 130, Number of board states: 62
# Processed GameId: 131, Number of board states: 72
# Processed GameId: 132, Number of board states: 49
# Processed GameId: 133, Number of board states: 75
# Processed GameId: 134, Number of board states: 60
# Processed GameId: 135, Number of board states: 45
# Processed GameId: 136, Number of board states: 67
# Processed GameId: 137, Number of board states: 64
# Processed GameId: 138, Number of board states: 67
# Processed GameId: 139, Number of board states: 72
# Processed GameId: 140, Number of board states: 87
# Processed GameId: 141, Number of board states: 36
# Processed GameId: 142, Number of board states: 73
# Processed GameId: 143, Number of board states: 31
# Processed GameId: 144, Number of board states: 32
# Processed GameId: 145, Number of board states: 42
# Processed GameId: 146, Number of board states: 101
# Processed GameId: 147, Number of board states: 34
# Processed GameId: 148, Number of board states: 67
# Processed GameId: 149, Number of board states: 78
# Processed GameId: 150, Number of board states: 56
# Processed GameId: 151, Number of board states: 128
# Processed GameId: 152, Number of board states: 80
# Processed GameId: 153, Number of board states: 121
# Processed GameId: 154, Number of board states: 49
# Processed GameId: 155, Number of board states: 113
# Processed GameId: 156, Number of board states: 32
# Processed GameId: 157, Number of board states: 126
# Processed GameId: 158, Number of board states: 84
# Processed GameId: 159, Number of board states: 59
# Processed GameId: 160, Number of board states: 76
# Processed GameId: 161, Number of board states: 45
# Processed GameId: 162, Number of board states: 45
# Finished processing all games.

# %%
import io
import chess.pgn
import chess.svg
import pandas as pd
from sqlalchemy import create_engine
import os

# Create the SQLAlchemy engine (use your actual credentials)
engine = create_engine('postgresql://postgres:anypass@localhost:5432/chess-ml')

# Games Table
games = "SELECT * FROM games;"
df_table1 = pd.read_sql(games, engine)

# Moves Table
moves = "SELECT * FROM moves;"
df_table2 = pd.read_sql(moves, engine)

# Players Table
players = "SELECT * FROM players;"
df_table3 = pd.read_sql(players, engine)

pgn_data = df_table1['pgn']  # Extract the PGN column

# Function to convert PGN string to board states
def pgn_to_board_states(pgn_string):
    pgn = io.StringIO(pgn_string)  # Convert the PGN string to a file-like object
    game = chess.pgn.read_game(pgn)  # Parse the game
    board_states = []
    board = game.board()

    # Loop through the moves and save the board state
    for move in game.mainline_moves():
        board.push(move)
        board_states.append(board.copy())  # Save a copy of the board after each move
    
    return board_states

# Function to generate and save SVG images of each board state
def generate_move_svgs(game_id, board_states):
    svg_files = []
    output_dir = f'game_{game_id}_svgs'
    
    # Create a directory for the game if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Loop through the board states and create SVG images
    for i, board in enumerate(board_states):
        # Generate the SVG representation of the board
        board_svg = chess.svg.board(board=board)
        
        # Save the SVG file
        svg_path = os.path.join(output_dir, f'move_{i+1}.svg')
        with open(svg_path, 'w') as f:
            f.write(board_svg)
        
        svg_files.append(svg_path)

    return svg_files

# Dictionary to store board states by GameId
game_board_states = {}

# Loop through all games in the DataFrame
for index, row in df_table1.iterrows():
    game_id = row['game_id']  # Extract GameId
    pgn_string = row['pgn']  # Extract PGN string
    try:
        # Generate the board states for the current game
        board_states = pgn_to_board_states(pgn_string)
        
        # Save the board states for the game in the dictionary
        game_board_states[game_id] = board_states
        print(f"Processed GameId: {game_id}, Number of board states: {len(board_states)}")
    
    except Exception as e:
        print(f"Failed to process GameId: {game_id} due to error: {e}")

print("Finished processing all games.")

# Function to get SVG images for a specified game
def get_game_svgs(game_id):
    if game_id in game_board_states:
        board_states = game_board_states[game_id]
        svgs = generate_move_svgs(game_id, board_states)
        print(f"Generated {len(svgs)} SVGs for GameId: {game_id}")
        return svgs
    else:
        print(f"No data available for GameId: {game_id}")
        return None

# Example usage
game_id_to_view = 12  # Replace with the actual game ID
get_game_svgs(game_id_to_view)
# Out:
# Processed GameId: 1, Number of board states: 56
# Processed GameId: 2, Number of board states: 57
# Processed GameId: 3, Number of board states: 79
# Processed GameId: 4, Number of board states: 90
# Processed GameId: 5, Number of board states: 74
# Processed GameId: 6, Number of board states: 54
# Processed GameId: 7, Number of board states: 76
# Processed GameId: 8, Number of board states: 94
# Processed GameId: 9, Number of board states: 137
# Processed GameId: 30, Number of board states: 25
# Processed GameId: 10, Number of board states: 85
# Processed GameId: 11, Number of board states: 68
# Processed GameId: 12, Number of board states: 65
# Processed GameId: 13, Number of board states: 48
# Processed GameId: 14, Number of board states: 79
# Processed GameId: 15, Number of board states: 53
# Processed GameId: 16, Number of board states: 31
# Processed GameId: 17, Number of board states: 139
# Processed GameId: 18, Number of board states: 49
# Processed GameId: 19, Number of board states: 121
# Processed GameId: 20, Number of board states: 100
# Processed GameId: 21, Number of board states: 135
# Processed GameId: 22, Number of board states: 64
# Processed GameId: 23, Number of board states: 71
# Processed GameId: 24, Number of board states: 49
# Processed GameId: 25, Number of board states: 86
# Processed GameId: 26, Number of board states: 51
# Processed GameId: 27, Number of board states: 117
# Processed GameId: 28, Number of board states: 29
# Processed GameId: 29, Number of board states: 61
# Processed GameId: 31, Number of board states: 30
# Processed GameId: 32, Number of board states: 127
# Processed GameId: 33, Number of board states: 40
# Processed GameId: 34, Number of board states: 101
# Processed GameId: 35, Number of board states: 56
# Processed GameId: 36, Number of board states: 91
# Processed GameId: 37, Number of board states: 55
# Processed GameId: 38, Number of board states: 68
# Processed GameId: 39, Number of board states: 45
# Processed GameId: 40, Number of board states: 35
# Processed GameId: 41, Number of board states: 59
# Processed GameId: 42, Number of board states: 41
# Processed GameId: 43, Number of board states: 46
# Processed GameId: 44, Number of board states: 46
# Processed GameId: 45, Number of board states: 55
# Processed GameId: 46, Number of board states: 35
# Processed GameId: 47, Number of board states: 50
# Processed GameId: 48, Number of board states: 75
# Processed GameId: 49, Number of board states: 89
# Processed GameId: 50, Number of board states: 49
# Processed GameId: 51, Number of board states: 85
# Processed GameId: 52, Number of board states: 23
# Processed GameId: 53, Number of board states: 77
# Processed GameId: 54, Number of board states: 43
# Processed GameId: 55, Number of board states: 67
# Processed GameId: 56, Number of board states: 54
# Processed GameId: 57, Number of board states: 10
# Processed GameId: 58, Number of board states: 47
# Processed GameId: 59, Number of board states: 77
# Processed GameId: 60, Number of board states: 79
# Processed GameId: 61, Number of board states: 29
# Processed GameId: 62, Number of board states: 45
# Processed GameId: 63, Number of board states: 67
# Processed GameId: 64, Number of board states: 70
# Processed GameId: 65, Number of board states: 23
# Processed GameId: 66, Number of board states: 83
# Processed GameId: 67, Number of board states: 47
# Processed GameId: 68, Number of board states: 136
# Processed GameId: 69, Number of board states: 60
# Processed GameId: 70, Number of board states: 42
# Processed GameId: 71, Number of board states: 92
# Processed GameId: 72, Number of board states: 73
# Processed GameId: 73, Number of board states: 77
# Processed GameId: 74, Number of board states: 38
# Processed GameId: 75, Number of board states: 89
# Processed GameId: 76, Number of board states: 72
# Processed GameId: 77, Number of board states: 150
# Processed GameId: 78, Number of board states: 80
# Processed GameId: 79, Number of board states: 59
# Processed GameId: 80, Number of board states: 38
# Processed GameId: 81, Number of board states: 98
# Processed GameId: 82, Number of board states: 37
# Processed GameId: 83, Number of board states: 38
# Processed GameId: 84, Number of board states: 54
# Processed GameId: 85, Number of board states: 33
# Processed GameId: 86, Number of board states: 73
# Processed GameId: 87, Number of board states: 120
# Processed GameId: 88, Number of board states: 84
# Processed GameId: 89, Number of board states: 50
# Processed GameId: 90, Number of board states: 63
# Processed GameId: 91, Number of board states: 51
# Processed GameId: 92, Number of board states: 97
# Processed GameId: 93, Number of board states: 70
# Processed GameId: 94, Number of board states: 102
# Processed GameId: 95, Number of board states: 19
# Processed GameId: 96, Number of board states: 67
# Processed GameId: 97, Number of board states: 53
# Processed GameId: 98, Number of board states: 45
# Processed GameId: 99, Number of board states: 82
# Processed GameId: 100, Number of board states: 50
# Processed GameId: 101, Number of board states: 78
# Processed GameId: 102, Number of board states: 51
# Processed GameId: 103, Number of board states: 67
# Processed GameId: 104, Number of board states: 109
# Processed GameId: 105, Number of board states: 71
# Processed GameId: 106, Number of board states: 70
# Processed GameId: 118, Number of board states: 56
# Processed GameId: 107, Number of board states: 65
# Processed GameId: 108, Number of board states: 67
# Processed GameId: 109, Number of board states: 101
# Processed GameId: 110, Number of board states: 62
# Processed GameId: 111, Number of board states: 40
# Processed GameId: 112, Number of board states: 48
# Processed GameId: 113, Number of board states: 57
# Processed GameId: 114, Number of board states: 47
# Processed GameId: 115, Number of board states: 47
# Processed GameId: 116, Number of board states: 37
# Processed GameId: 117, Number of board states: 98
# Processed GameId: 119, Number of board states: 90
# Processed GameId: 120, Number of board states: 59
# Processed GameId: 121, Number of board states: 92
# Processed GameId: 122, Number of board states: 119
# Processed GameId: 123, Number of board states: 92
# Processed GameId: 124, Number of board states: 36
# Processed GameId: 125, Number of board states: 39
# Processed GameId: 126, Number of board states: 81
# Processed GameId: 127, Number of board states: 29
# Processed GameId: 128, Number of board states: 45
# Processed GameId: 129, Number of board states: 67
# Processed GameId: 130, Number of board states: 62
# Processed GameId: 131, Number of board states: 72
# Processed GameId: 132, Number of board states: 49
# Processed GameId: 133, Number of board states: 75
# Processed GameId: 134, Number of board states: 60
# Processed GameId: 135, Number of board states: 45
# Processed GameId: 136, Number of board states: 67
# Processed GameId: 137, Number of board states: 64
# Processed GameId: 138, Number of board states: 67
# Processed GameId: 139, Number of board states: 72
# Processed GameId: 140, Number of board states: 87
# Processed GameId: 141, Number of board states: 36
# Processed GameId: 142, Number of board states: 73
# Processed GameId: 143, Number of board states: 31
# Processed GameId: 144, Number of board states: 32
# Processed GameId: 145, Number of board states: 42
# Processed GameId: 146, Number of board states: 101
# Processed GameId: 147, Number of board states: 34
# Processed GameId: 148, Number of board states: 67
# Processed GameId: 149, Number of board states: 78
# Processed GameId: 150, Number of board states: 56
# Processed GameId: 151, Number of board states: 128
# Processed GameId: 152, Number of board states: 80
# Processed GameId: 153, Number of board states: 121
# Processed GameId: 154, Number of board states: 49
# Processed GameId: 155, Number of board states: 113
# Processed GameId: 156, Number of board states: 32
# Processed GameId: 157, Number of board states: 126
# Processed GameId: 158, Number of board states: 84
# Processed GameId: 159, Number of board states: 59
# Processed GameId: 160, Number of board states: 76
# Processed GameId: 161, Number of board states: 45
# Processed GameId: 162, Number of board states: 45
# Finished processing all games.
# Generated 65 SVGs for GameId: 12
# ['game_12_svgs\\move_1.svg',
#  'game_12_svgs\\move_2.svg',
#  'game_12_svgs\\move_3.svg',
#  'game_12_svgs\\move_4.svg',
#  'game_12_svgs\\move_5.svg',
#  'game_12_svgs\\move_6.svg',
#  'game_12_svgs\\move_7.svg',
#  'game_12_svgs\\move_8.svg',
#  'game_12_svgs\\move_9.svg',
#  'game_12_svgs\\move_10.svg',
#  'game_12_svgs\\move_11.svg',
#  'game_12_svgs\\move_12.svg',
#  'game_12_svgs\\move_13.svg',
#  'game_12_svgs\\move_14.svg',
#  'game_12_svgs\\move_15.svg',
#  'game_12_svgs\\move_16.svg',
#  'game_12_svgs\\move_17.svg',
#  'game_12_svgs\\move_18.svg',
#  'game_12_svgs\\move_19.svg',
#  'game_12_svgs\\move_20.svg',
#  'game_12_svgs\\move_21.svg',
#  'game_12_svgs\\move_22.svg',
#  'game_12_svgs\\move_23.svg',
#  'game_12_svgs\\move_24.svg',
#  'game_12_svgs\\move_25.svg',
#  'game_12_svgs\\move_26.svg',
#  'game_12_svgs\\move_27.svg',
#  'game_12_svgs\\move_28.svg',
#  'game_12_svgs\\move_29.svg',
#  'game_12_svgs\\move_30.svg',
#  'game_12_svgs\\move_31.svg',
#  'game_12_svgs\\move_32.svg',
#  'game_12_svgs\\move_33.svg',
#  'game_12_svgs\\move_34.svg',
#  'game_12_svgs\\move_35.svg',
#  'game_12_svgs\\move_36.svg',
#  'game_12_svgs\\move_37.svg',
#  'game_12_svgs\\move_38.svg',
#  'game_12_svgs\\move_39.svg',
#  'game_12_svgs\\move_40.svg',
#  'game_12_svgs\\move_41.svg',
#  'game_12_svgs\\move_42.svg',
#  'game_12_svgs\\move_43.svg',
#  'game_12_svgs\\move_44.svg',
#  'game_12_svgs\\move_45.svg',
#  'game_12_svgs\\move_46.svg',
#  'game_12_svgs\\move_47.svg',
#  'game_12_svgs\\move_48.svg',
#  'game_12_svgs\\move_49.svg',
#  'game_12_svgs\\move_50.svg',
#  'game_12_svgs\\move_51.svg',
#  'game_12_svgs\\move_52.svg',
#  'game_12_svgs\\move_53.svg',
#  'game_12_svgs\\move_54.svg',
#  'game_12_svgs\\move_55.svg',
#  'game_12_svgs\\move_56.svg',
#  'game_12_svgs\\move_57.svg',
#  'game_12_svgs\\move_58.svg',
#  'game_12_svgs\\move_59.svg',
#  'game_12_svgs\\move_60.svg',
#  'game_12_svgs\\move_61.svg',
#  'game_12_svgs\\move_62.svg',
#  'game_12_svgs\\move_63.svg',
#  'game_12_svgs\\move_64.svg',
#  'game_12_svgs\\move_65.svg']
